# %%
def average_by_key(rows):
    total = 0
    count = 0
    for r in rows:
        if "score" in r:
            total += r["score"]
            count += 1
    if count == 0:
        return 0
    return total / count

print(average_by_key([{"score": 5}, {"score": 7}, {"x": 1}]))  # Expected Output: 6.0
print(average_by_key([]))   # Expected Output: 0
# Out:
# 6.0
# 0

# %%
def even_numbers(nums):
    even_numbers=[]
    for n in nums:
        if n % 2 == 0:
            even_numbers.append(n)
    return even_numbers

print(even_numbers([1,2,3,4,5,6])) # Expected Output: [2, 4, 6]
# Out:
# [2, 4, 6]

# %%
class Artist:
    def __init__(self, name, fee):
        self.name = name
        self.__fee = fee #private attribute, do not change this.

    def add_charges(self, additional_charges):
        self.__fee = self.__fee + additional_charges

    def get_fee(self):
        return self.__fee

a1 = Artist("Taylor Swift", 50)
a2 = Artist("Lisa", 65)
a1.add_charges(20)
a2.add_charges(20)
print("Taylor Swift fee=", a1.get_fee()) # Expected Output: 70
print("Lisa fee=", a2.get_fee()) # Expected Output: 85
# Out:
# Taylor Swift fee= 70
# Lisa fee= 85

# %% [markdown]
# Develop a python program to create text file with three lines. (File name - Student_ID_CVE.txt)
#
# Hello! Welcome to KMUTT.
#
# We are Civil Engineering Students.
#
# We don't want to learn programming T_T

# %%
# Write your program here
with open("68070503244_CVE.txt", "w") as f:
    f.write("Hello! Welcome to KMUTT.\n")
    f.write("We are Civil Engineering Students.\n")
    f.write("We don't want to learn programming T_T\n")
    f.close()

# %% [markdown]
# Develop a python program to read previous text file line by line and print second line.
#
# Expected output:
# We are Civil Engineering Students.

# %%
# Write your program here
with open("Student_ID_CVE.txt", "r") as f:
    lines = f.readlines()

print(lines[1].strip())
# Out:
# We are Civil Engineering Students.
